# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from gensim.summarization import summarize
from konlpy.tag import Komoran; komoran=Komoran()

# %%
def Crawling_Article(url,sid2): # get one articla data
    
    response = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
    if response.status_code==200:
        bsoup = BeautifulSoup(response.content, "html.parser", from_encoding='utf-8')
        try: #Error article catch
            crw_title = bsoup.select('div.content div.article_header div.article_info h3')
            crw_text = summarize(bsoup.select("div.content div._article_body_contents")[0].get_text().replace('\n', "").replace("    동영상 뉴스   ", "").replace("// flash 오류를 우회하기 위한 함수 추가", "").replace("function _flash_removeCallback() {}","").replace("// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}",""),word_count=50).replace("\n","")
            Crw_Title = crw_title[0].get_text()
            print(crw_text)
        except IndexError:
            print(url)
            Crw_Title = "제목없음"
        except ValueError:
            crw_text="내용없음"
            print("\n\n내용없음\n\n")
        news_data = {
            'Title' : crw_title[0].get_text(),
            'Content' : crw_text,
            'Sid_Number' : sid2,
        }
        komoran.nouns(crw_title[0].get_text())

# %%
def Crawling_URL(url,sid2): #get url in news categorys

    URL = url
#     URL = "https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=104&sid2=234"
    response = requests.get(URL, headers={'User-Agent':'Mozilla/5.0'})
    
    if response.status_code==200:
        bsoup = BeautifulSoup(response.content, "html.parser", from_encoding='utf-8')
    #   print(bsoup)
    #   print(len(bsoup.select('div.list_body a')))
        url_list = bsoup.select('div.list_body dt.photo a')
        
        for i in range(len(url_list)):
#             crw_url = url_list[i]["href"]
#             if crw_url==None:
#                 print("a")
#             else:
#                 print(crw_url)
            Crawling_Article(url_list[i]["href"],sid2) #crawing article with crawled url

# %%
def Crawling_naver_news_category(): #get naver news url with sid1, sid2
    
    sid1 = [100,101,102,103,104,105]
    sid2 = [
        ["264","265","268","266","267","269"], #정치
        ["259","258","261","771","260","262","310","263"], #경제
        ["249","250","251","254","252","59b","255","256","276","257"], #사회
        ["241","239","240","267","238","376","242","243","244","248","245"], #생활문화
        ["231","232","233","234","322"], #세계
        ["731","226","227","230","732","283","229","228"] #IT과학
    ]
    
    for sid1_num in sid1:
        for sid2_num in sid2[sid1_num%100]:
    #         print(sid2_num)

            url = (
                "https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&"
                + "sid2=" + sid2_num
                + "&sid1=" + str(sid1_num)
    #             + "&date="
    #             + "&page="+page_num
            )
            Crawling_URL(url,sid2_num)

# %%
if __name__ == '__main__':
    Crawling_naver_news_category()
# Out:
# 국민의힘 오세훈 서울시장 후보가 7일 서울 여의도 국민의힘 중앙당사 개표상황실에서 방송3사(KBS,MBC,SBS) 공동 출구 조사 결과발표에서 더불어민주당 박영선 서울시장 후보를 앞서는 걸로 예측되자 김종인 비대위원장 등과 함께 기뻐하고 있다.연합뉴스더불어민주당 김태년 당대표 직무대행이 7일 서울 여의도 중앙당사 개표상황실에서 방송3사(KBS,MBC,SBS) 공동 출구 조사 결과 국민의힘 오세훈 서울시장 후보가 더불어민주당 박영선 서울시장 후보를 앞서는 걸로 예측되자 굳은 표정을 짓고 있다 .
# [머니투데이 정진우 기자]  [서울=뉴시스]박영태 기자 = 문재인 대통령이 5일 청와대 여민관에서 열린 수석 보좌관회의에 참석해 발언하고 있다.그동안 문재인정부 총리가 이낙연, 정세균 등 호남 출신이었기 때문에 지역 안배 등 차원에서 김 전 의원 이름이 자주 거론된다.노무현정부 청와대 경제수석 출신으로 문 대통령과 함께 일한 김영주 전 무역협회장의 이름도 나온다.
#
# 가운데는 우태희 대한상의 상근부회장.2021.4.7 scape@yna.co.kr(서울=연합뉴스) 임형섭 기자 = 이호승 청와대 정책실장이 7일 서울 중구 대한상공회의소와 여의도 중소기업중앙회를 차례로 방문했다.우태희 대한상의 상근부회장 역시 "기업들이 부담스러워하는 법들에 대해 더 관심을 가져달라"고 했다.이에 김 회장은 "정책실장의 경제단체 방문은 의미가 있는 일"이라며 "납품단가조정권, 중소기업기본법 등 잘 만들어진 정책들이 제대로 작동하도록 청와대가 역할을 해달라"고 말했다.
# 최 회장은 “규제를 풀려면 법과 규제가 있음으로써 불편한 정도나 범위가 얼마만큼일 지 평가하고 인과관계를 추적하는 시스템이 필요하다”면서 “규제가 어떤 문제가 있는지 데이터화해야 한다”고 말했다.이호승 청와대 정책실장이 7일 서울 여의도 중기중앙회에서 김기문 중기중앙회 회장을 만나 대화하고 있다.
# 7일 충남 태안군 남면 달산리를 찾은 한 관광객이 도로변에 만개한 벚꽃을 카메라로 찍고 있다.삼면이 바다인 충남 태안은 해양성 기후라 내륙보다 벚꽃이 일주일 이상 늦게 핀다./태안=연합뉴스[서울경제] /안현덕 기자 always@sedaily.com▶ 상위 1% 투자자 픽![주식 초고수는 지금]▶ 서울경제 더 폴리틱스 뉴스를 만나보세요!▶ 네이버 채널에서 '서울경제' 구독해주세요!저작권자 ⓒ 서울경제, 무단 전재 및 재배포 금지
#
# [서울=뉴시스]이호승 청와대 정책실장이 7일 오후 서울 중구 대한상공회의소를 방문해 최태원 대한상의회장과 면담하기 앞서 기념촬영을 하고 있다.photo@newsis.com *재판매 및 DB 금지[서울=뉴시스] 박정규 기자 = 최태원 대한상공회의소 회장이 7일 이호승 신임 청와대 정책실장과 만나 "소통의 플랫폼 역할을 하겠다"고 말했다.이에 이 실장은 "앞으로 상의, 기업과 자주 만나겠다"고 약속했다.이날 최 회장과의 면담을 시작으로 이 실장은 재계와의 만남을 이어나갈 예정이다.
# 그 생각만 하면 너무 슬프고 자존심 상합니다.”국내 라이브 클럽의 성지로 불리는 홍대 앞에서 20년 가까이 라이브 클럽을 운영 중인 황 모 대표는 근황을 묻자 “클럽이 공연을 못하니 좋을 수 있겠냐”며 길게 한숨을 내쉬었다.
# (서울=연합뉴스) 이호승 청와대 정책실장(왼쪽 두번째)이 7일 오후 서울 중구 대한상공회의소를 방문해 최태원 대한상의회장(오른쪽 두번째)과 면담하고 있다.2021.4.7 [청와대 제공.재판매 및 DB금지]    photo@yna.co.kr▶네이버에서도 뉴스는 연합뉴스[구독 클릭]▶[팩트체크] 박영선-오세훈 TV토론 말말말▶제보하기<저작권자(c) 연합뉴스(https://www.yna.co.kr/), 무단 전재-재배포 금지>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-60e6b788ed7f> in <module>
#       1 if __name__ == '__main__':
# ----> 2     Crawling_naver_news_category()
#
# <ipython-input-5-7c35cb65d0d2> in Crawling_naver_news_category()
#      22     #             + "&page="+page_num
#      23             )
# ---> 24             Crawling_URL(url,sid2_num)
#
# <ipython-input-4-ea487a791468> in Crawling_URL(url, sid2)
#      17 #             else:
#      18 #                 print(crw_url)
# ---> 19             Crawling_Article(url_list[i]["href"],sid2) #crawing article with crawled url
#
# <ipython-input-3-eecaa7c749f8> in Crawling_Article(url, sid2)
#       1 def Crawling_Article(url,sid2): # get one articla data
#       2
# ----> 3     response = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
#       4     if response.status_code==200:
#       5         bsoup = BeautifulSoup(response.content, "html.parser", from_encoding='utf-8')
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\requests\models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     569         """
#     570         if self.chunked and self.supports_chunked_reads():
# --> 571             for line in self.read_chunked(amt, decode_content=decode_content):
#     572                 yield line
#     573         else:
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     761
#     762             while True:
# --> 763                 self._update_chunk_length()
#     764                 if self.chunk_left == 0:
#     765                     break
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     691         if self.chunk_left is not None:
#     692             return
# --> 693         line = self._fp.fp.readline()
#     694         line = line.split(b";", 1)[0]
#     695         try:
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\wjstm\anaconda3\envs\tensorflow\lib\ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
